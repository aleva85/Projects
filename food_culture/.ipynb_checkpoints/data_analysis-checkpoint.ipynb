# %% [markdown]
# # Practising visaulization and ML on a food dataset
#
# this script perfoms exploratory analysis on the "what's cooking?" dataset from Kaggle, and develops a random forest classifier to predict dish nationality based on the ingredients

# %%
import pandas as pd
import matplotlib.pyplot as plt

train_df = pd.read_json('train.json')
train_df.head()
# Out:
#        cuisine     id                                        ingredients
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
ax = train_df['cuisine'].value_counts().plot(kind = 'bar', 
                                             title = "Cuisine types", 
                                             figsize = (8, 3), 
                                             legend = False)
ax.set_ylabel("recipes", fontsize=12)
plt.show()

# %% [markdown]
# ##### note that some cuisines are more frequent than others
# this could be an issue when training and testing classification and regression models. consider stratified sampling

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# first, select a stratified random sample of the data (30%), so it doesn't take ages...
# I will use the StratifiedShuffleSplit method, not sure there is something more appropriate
split = StratifiedShuffleSplit(n_splits = 1, test_size = .7, random_state = 42)
for keep_idx, drop_idx in split.split(train_df, train_df['cuisine']): # guarantee that ratios of cuisine are respected
    small_dataset = train_df.iloc[keep_idx]
print('original dataset size',len(train_df), 'reduced dataset size', len(small_dataset))

# graphically check that dataset is reduced to 30%, and ratios are maintained
figure, (ax1, ax2) = plt.subplots(1,2)
train_df['cuisine'].value_counts().plot(ax = ax1, kind='bar', title ="Cuisine types", figsize=(15, 3), legend=True, fontsize=12)
small_dataset['cuisine'].value_counts().plot(ax = ax2, kind='bar', title ="Cuisine types", figsize=(15, 3), legend=True, fontsize=12)
plt.show()
# Out:
# original dataset size 39774 reduced dataset size 11932

# %% [markdown]
# ### now the machine learning part
# First, we make a matrix that, for every recipe (row) and for every ingredient (col),
# there is 1 if the recipe uses that ingredient, and 0 otherwise.

# %%
# first, isolate the ingredients
ingredients = []
for recipe in small_dataset.ingredients:
    ingredients.extend(recipe)
    
# here an idea to make computation time more manageable: get first rid of less frequent ingredients
from collections import Counter
ingredients_counts = Counter(ingredients) # more efficient than iterating (O(n) vs O(n^2))
frequent_ingredients = {}
for key, value in ingredients_counts.items():
    if value > 0:  # put a higher threshold if willing to sacrifice performances for speed
        frequent_ingredients.update({str(key):value})
print('total ingredients: ', len(ingredients_counts), '; ingredients preserved: ', len(frequent_ingredients))
# Out:
# total ingredients:  4746 ; ingredients preserved:  4746

# %%
# find a unique list of ingredients and cuisines
unique_ingredients = list(set(frequent_ingredients))
cuisines = small_dataset['cuisine'].unique()

# now create a matrix that, for each recipe and for each ingredient, has 1 if the ingredient is present in the recipe and 0 otherwise.
# this code won't scale up very well, we should think about more efficient solutions
X = np.zeros(shape = (len(small_dataset), len(frequent_ingredients)))
i = 0
j = 0
for recipe in small_dataset.ingredients:
    for ingredient in frequent_ingredients:    # loop all keys. this is probably inefficient, I could loop over the recipe only
        X[i,j] = 1 if ingredient in recipe else 0
        j += 1
    j = 0
    i += 1

# %%
# now, devide the small dataset in train and test sets (80/20 ratio), again with stratified sampling
split = StratifiedShuffleSplit(n_splits = 1, test_size = .2, random_state = 42)
for train_idx, test_idx in split.split(small_dataset, small_dataset['cuisine']): 
    X_train = X[train_idx,:]
    Y_train = small_dataset['cuisine'].iloc[train_idx]
    X_test = X[test_idx,:]
    Y_test = small_dataset['cuisine'].iloc[test_idx]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

forest_clf = RandomForestClassifier(random_state=42, min_samples_split = 10)
# Declare hyperparameters to tune
hyperparameters = {'n_estimators': [5, 30],
                   'max_depth': [100, 200, 300]
                  }
 
# Tune model using cross-validation pipeline
clf = GridSearchCV(forest_clf, hyperparameters, cv=10)
rfc = clf.fit(X_train, Y_train)

# let's look at performances...
y_pred_rf = clf.predict(X_test)
print('model accuracy: ', metrics.accuracy_score(Y_test, y_pred_rf))
print("Best parameters set found on test set:", clf.best_params_)
# Out:
# model accuracy:  0.643904482614
# Best parameters set found on test set: {'max_depth': 200, 'n_estimators': 30}

# %%
importance = pd.DataFrame(rfc.best_estimator_.feature_importances_, index = frequent_ingredients, columns=["Importance"])

importance_plot = importance.sort_values('Importance',ascending=False )[:20]
importance_plot.plot(kind='bar', title ="Importance", figsize=(8, 3), legend=True, fontsize=12)
plt.show()

# %%
# just a final curiosity, parmesan seems like the most important feature, I wonder if it is associated to a single cousine or not. 
# Somehow, I suspect it is particularly good at predicting italian food.
# but how can I test this??

# [TODO]
